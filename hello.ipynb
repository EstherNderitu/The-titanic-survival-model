# %%
import pandas as pd
import numpy as np


data = pd.read_csv('titanic3.csv')
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])

data.replace({'male': 1, 'female': 0}, inplace=True)
data.corr(numeric_only=True).abs()[["survived"]]

data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr(numeric_only=True).abs()[["survived"]]    

data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)

from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))

from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

model.summary()

model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)

y_pred = np.rint(model.predict(X_test).flatten())
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.7464114832535885
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 5)                 30
#
#  dense_22 (Dense)            (None, 5)                 30
#
#  dense_23 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 27/27 [==============================] - 3s 5ms/step - loss: 0.6924 - accuracy: 0.5813
# Epoch 2/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6905 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6867 - accuracy: 0.5897
# Epoch 4/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6786 - accuracy: 0.7057
# Epoch 5/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6636 - accuracy: 0.7667
# Epoch 6/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6419 - accuracy: 0.7715
# Epoch 7/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6147 - accuracy: 0.7763
# Epoch 8/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5862 - accuracy: 0.7715
# Epoch 9/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5603 - accuracy: 0.7703
# Epoch 10/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5369 - accuracy: 0.7679
# Epoch 11/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5171 - accuracy: 0.7715
# Epoch 12/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5010 - accuracy: 0.7787
# Epoch 13/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4882 - accuracy: 0.7787
# Epoch 14/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4783 - accuracy: 0.7751
# Epoch 15/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4721 - accuracy: 0.7799
# Epoch 16/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4667 - accuracy: 0.7835
# Epoch 17/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4625 - accuracy: 0.7847
# Epoch 18/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.4590 - accuracy: 0.7883
# Epoch 19/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4565 - accuracy: 0.7871
# Epoch 20/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4547 - accuracy: 0.7871
# Epoch 21/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4528 - accuracy: 0.7883
# Epoch 22/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4515 - accuracy: 0.7883
# Epoch 23/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4504 - accuracy: 0.7919
# Epoch 24/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4503 - accuracy: 0.7871
# Epoch 25/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4490 - accuracy: 0.7883
# Epoch 26/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4485 - accuracy: 0.7859
# Epoch 27/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4480 - accuracy: 0.7811
# Epoch 28/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4471 - accuracy: 0.7811
# Epoch 29/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4464 - accuracy: 0.7847
# Epoch 30/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4462 - accuracy: 0.7859
# Epoch 31/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4465 - accuracy: 0.7799
# Epoch 32/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4462 - accuracy: 0.7811
# Epoch 33/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4455 - accuracy: 0.7859
# Epoch 34/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4455 - accuracy: 0.7895
# Epoch 35/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.4450 - accuracy: 0.7847
# Epoch 36/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4455 - accuracy: 0.7835
# Epoch 37/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4454 - accuracy: 0.7787
# Epoch 38/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4450 - accuracy: 0.7799
# Epoch 39/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4447 - accuracy: 0.7823
# Epoch 40/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4447 - accuracy: 0.7907
# Epoch 41/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4448 - accuracy: 0.7883
# Epoch 42/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4447 - accuracy: 0.7799
# Epoch 43/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4445 - accuracy: 0.7859
# Epoch 44/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4449 - accuracy: 0.7859
# Epoch 45/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4445 - accuracy: 0.7883
# Epoch 46/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4444 - accuracy: 0.7847
# Epoch 47/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4447 - accuracy: 0.7859
# Epoch 48/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4441 - accuracy: 0.7859
# Epoch 49/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4441 - accuracy: 0.7883
# Epoch 50/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4439 - accuracy: 0.7859
# 7/7 [==============================] - 0s 3ms/step
# 0.7894736842105263
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 60
#      57 y_pred = np.rint(model.predict(X_test).flatten())
#      58 print(metrics.accuracy_score(y_test, y_pred))
# ---> 60 count_row = df.shape[0]
#      61 print(count_row)
#
# NameError: name 'df' is not defined
